# %% [markdown]
# # Task 4.9: Ibra Lisso
#
# ---------------------------------

# %% [markdown]
# # Part 1 Task

# %% [markdown]
# <b>1.1. Download the customer data set and add it to your “Original Data” folder.
#
# <b>1.2. Create a new notebook in your “Scripts” folder for part 1 of this task.
#
#     Directives Completed

# %% [markdown]
# # 01. Importing Libraries
#
# <b>Import your analysis libraries, as well as your new customer data set as a dataframe.

# %%
#Importing Libraries;

import numpy as np
import pandas as pd
import os

# %%
#Creating a Folderpath; 

path = '/users/ibu/Documents/12-2022 Instacart Basket Analysis'

# %%
#Importing the 'Customers Dataset' from 'Original Data' Folder

Customers_Dataset = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'customers_data.csv'))

# %%
#Checking Data Columns

Customers_Dataset.head()
# Out:
#    user_id First Name    Surnam  Gender       STATE  Age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    n_dependants fam_status  income
# 0             3    married  165665
# 1             0     single   59285
# 2             2    married   99568
# 3             0     single   42049
# 4             1    married   40374

# %% [markdown]
# <b>Notes:</b>
#
# #Updating all headers into 'small caps'
#
# #Fixing columns [n-dependants = total_dependants & fam_status = marital_status]

# %%
#Checking dataset shape

Customers_Dataset.shape
# Out:
# (206209, 10)

# %%
#Performing Descriptive Statitics to Get Clues; 

Customers_Dataset.describe()
# Out:
#              user_id            age  total_dependents         income
# count  206209.000000  206209.000000     206209.000000  206209.000000
# mean   103105.000000      49.501646          1.499823   94632.852548
# std     59527.555167      18.480962          1.118433   42473.786988
# min         1.000000      18.000000          0.000000   25903.000000
# 25%     51553.000000      33.000000          0.000000   59874.000000
# 50%    103105.000000      49.000000          1.000000   93547.000000
# 75%    154657.000000      66.000000          3.000000  124244.000000
# max    206209.000000      81.000000          3.000000  593901.000000

# %% [markdown]
# <b>Notes:</b>
# 1. Oldest Customer is 81 years, Youngest is 18 years.
# 2. We some Customers have no dependents, most have more than 1 dependent
# 3. We can see no Customer earns more than 594,000 or lower than 25,000

# %% [markdown]
# # 02. Data Wrangling

# %%
#Fixing Column Headers by renaming each of them; 

Customers_Dataset.rename(columns = {'n_dependants': 'total_dependents'}, inplace = True)

Customers_Dataset.rename(columns = {'fam_status': 'marital_status'}, inplace = True)

# %%
#Fixing Column-Headers by Changing from 'CAPS' to 'caps'; 

Customers_Dataset.rename(columns = {'STATE': 'state'}, inplace = True)
Customers_Dataset.rename(columns = {'Surnam': 'last_name'}, inplace = True)
Customers_Dataset.rename(columns = {'First Name': 'first_name'}, inplace = True)
Customers_Dataset.rename(columns = {'Age': 'age'}, inplace = True)
Customers_Dataset.rename(columns = {'Gender': 'gender'}, inplace = True)

# %%
#Checking Columns Counts and Shape; 

Customers_Dataset.head()
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    total_dependents marital_status  income
# 0                 3        married  165665
# 1                 0         single   59285
# 2                 2        married   99568
# 3                 0         single   42049
# 4                 1        married   40374

# %%
Customers_Dataset.shape
# Out:
# (206209, 10)

# %% [markdown]
# <b>Notes:</b> Columns and Mispelled-Text Fixes completed and Customers Dataset Counts and Shape matches.

# %% [markdown]
# # 03. Performing Data Quality & Consistency Checks
#
#    <b>Guided Steps:</b> Missing Values<b>,</b> Duplicates & Mixed-Type Data.

# %%
#Finding Missing Data Values;

Customers_Dataset.isnull().sum()
# Out:
# user_id                 0
# first_name          11259
# last_name               0
# gender                  0
# state                   0
# age                     0
# date_joined             0
# total_dependents        0
# marital_status          0
# income                  0
# dtype: int64

# %% [markdown]
# <b>Notes:</b> Seems there are 11,259 missing First Names. That is equivalent to 11,259 rows in total.

# %%
#Checking the Missing Data values on 'first_name';

df_nan = Customers_Dataset[Customers_Dataset['first_name'].isnull() == True]

# %%
df_nan
# Out:
#         user_id first_name last_name  gender         state  age date_joined  \
# 53        76659        NaN   Gilbert    Male      Colorado   26    1/1/2017
# 73        13738        NaN     Frost  Female     Louisiana   39    1/1/2017
# 82        89996        NaN    Dawson  Female        Oregon   52    1/1/2017
# 99        96166        NaN   Oconnor    Male      Oklahoma   51    1/1/2017
# 105       29778        NaN    Dawson  Female          Utah   63    1/1/2017
# ...         ...        ...       ...     ...           ...  ...         ...
# 206038   121317        NaN    Melton    Male  Pennsylvania   28   3/31/2020
# 206044   200799        NaN  Copeland  Female        Hawaii   52    4/1/2020
# 206090   167394        NaN     Frost  Female        Hawaii   61    4/1/2020
# 206162   187532        NaN     Floyd  Female    California   39    4/1/2020
# 206171   116898        NaN   Delgado  Female      Colorado   23    4/1/2020
#
#         total_dependents marital_status  income
# ...

# %% [markdown]
# <b>Notes:</b> Yes, indeed 11,259 Customer's First Names are missing

# %%
#Performing Data Types Check of all Columns; 

Customers_Dataset.dtypes
# Out:
# user_id              int64
# first_name          object
# last_name           object
# gender              object
# state               object
# age                  int64
# date_joined         object
# total_dependents     int64
# marital_status      object
# income               int64
# dtype: object

# %%
#Checking on Mixed-Data Types; 

for col in Customers_Dataset.columns.tolist():
  weird = (Customers_Dataset[[col]].applymap(type) != Customers_Dataset[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (Customers_Dataset[weird]) > 0:
    print (col)
# Out:
# first_name

# %%
#Converting Data-Type 'First Name' to String;

Customers_Dataset['first_name'] = Customers_Dataset['first_name'].astype('str')

# %%
#Re-Checking for Mixed-Types after Converting 'First Name' into String;

for col in Customers_Dataset.columns.tolist():
  weird = (Customers_Dataset[[col]].applymap(type) != Customers_Dataset[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (Customers_Dataset[weird]) > 0:
    print (col)

# %% [markdown]
# <b>Notes:</b> No further Mixed-Types Data exists after conversion to strings of existing Mixed-Type data.

# %%
#Checking for any Data Duplicates; 

Customers_Dataset[Customers_Dataset.duplicated()]
# Out:
# Empty DataFrame
# Columns: [user_id, first_name, last_name, gender, state, age, date_joined, total_dependents, marital_status, income]
# Index: []

# %% [markdown]
# <b>Notes:</b> No duplicates exists. Dataset good on this part.

# %% [markdown]
# # 04. Combine the Datasets: 'Customers' & 'Instacart Orders_Products';
#
# <b>Key Hint:</b> Ensure the key columns matches (same data type)

# %%
#Importing the 'Ords_Prods_T48' Dataset' from 'Prepared Data' Folder;

df_Ords_Prods_T48 = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Ords_Prods_T48.pkl'))

# %%
#Checking 'Ords_Prods_T48' Dataset Columns and Rows; 

df_Ords_Prods_T48.head(5)
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  7                    15.0         196                  1
# 2                 12                    21.0         196                  1
# 3                  7                    29.0         196                  1
# 4                 15                    28.0         196                  1
#
#    reordered  ...   prices_range_loc     Busiest day    Busiest_days  \
# ...

# %%
#Re-Checking 'Customers_Dataset' Columns and Rows for common key 'column name'; 

Customers_Dataset.head(5)
# Out:
#    user_id first_name last_name  gender       state  age date_joined  \
# 0    26711    Deborah  Esquivel  Female    Missouri   48    1/1/2017
# 1    33890   Patricia      Hart  Female  New Mexico   36    1/1/2017
# 2    65803    Kenneth    Farley    Male       Idaho   35    1/1/2017
# 3   125935   Michelle     Hicks  Female        Iowa   40    1/1/2017
# 4   130797        Ann   Gilmore  Female    Maryland   26    1/1/2017
#
#    total_dependents marital_status  income
# 0                 3        married  165665
# 1                 0         single   59285
# 2                 2        married   99568
# 3                 0         single   42049
# 4                 1        married   40374

# %% [markdown]
# <b>Notes:</b> The key column we see between the two datasets: 'Customers_Dataset & Ords_Prods_T48 = <b>user_id</b>

# %%
#Checking the shape of 'df_Ords_Prods_T48' Dataset; 

df_Ords_Prods_T48.shape
# Out:
# (32404859, 26)

# %% [markdown]
# <b>Notes:</b>
#
# 1. <b>Customers_Dataset</b> has 206,209 Rows + 10 Columns
# 2. <b>df_Ords_Prods_T48</b> has 32,404,859 Rows + 26 Columns

# %%
#Carrying Out the Merging of the Two Datasets; 

Cust_Ords_Prods_T49 = df_Ords_Prods_T48.merge(Customers_Dataset, on = 'user_id')

# %%
#Checking the shape of 'Cust_Ords_Prods_T49' Dataset; 

Cust_Ords_Prods_T49.shape
# Out:
# (32404859, 35)

# %% [markdown]
# <b>Notes:</b> The new combined Cust_Ords_Prods dataset now has same 32,404,859 rows number, but more columns = 35

# %%
#Checking the Columns + Rows of the New 'Cust_Ords_Prods' Dataset;

Cust_Ords_Prods_T49.head(10)
# Out:
#    Unnamed: 0_x  order_id  user_id  order_number  orders_day_of_week  \
# 0             0   2539329        1             1                   2
# 1             1   2398795        1             2                   3
# 2             2    473747        1             3                   3
# 3             3   2254736        1             4                   4
# 4             4    431534        1             5                   4
# 5             5   3367565        1             6                   2
# 6             6    550135        1             7                   1
# 7             7   3108588        1             8                   1
# 8             8   2295261        1             9                   1
# 9             9   2550362        1            10                   4
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# ...

# %% [markdown]
# # 05. Exporting to 'Prepared Data' Folder as 'pkl'
#
# <b>Notes:</b> Shape and Columns Checked for verification purposes. Now time to export it for Part 2 of Task 4.9.

# %%
Cust_Ords_Prods_T49.to_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'Cust_Ords_Prods_T49A.pkl'))

# %%
Cust_Ords_Prods_T49.to_csv(os.path.join(path, '02 Data', 'Prepared Data', 'Cust_Ords_Prods_T49A.csv'))
